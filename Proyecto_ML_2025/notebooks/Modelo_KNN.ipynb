# %% [markdown]
# # Librerias

# %%
# Limpieza

import pandas as pd
import numpy as np
import sys

# Visualización

import matplotlib.pyplot as plt
import seaborn as sns

# Preprocesamiento

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler, minmax_scale

# Modelo 

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.inspection import permutation_importance

# %%
sys.path.append(r"C:/Users/gabri/Documents/Proyecto_ML_2025/src/utils/")

from Funciones import k_optimo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sys.path.append(r"C:/Users/gabri/Documents/Proyecto_ML_2025/src/utils/")
#       3 from Funciones import k_optimo
#
# NameError: name 'sys' is not defined

# %%
# Importamos  df

df = pd.read_csv('C:/Users/gabri/Documents/Proyecto_ML_2025/data/processed/super_shop_dataset_limpio_target.csv')

# %%
# Mostramos dataset

df.head()
# Out:
#    employee_id product_id product_name  price  discount  stock  sold_quantity  \
# 0          801      P1000       Item_D   2684        23    192             21
# 1          173      P1001       Item_A   2704        15     21             62
# 2          974      P1002       Item_C   3173         6     66             11
# 3          206      P1003       Item_D   4320        26    180              9
# 4          994      P1004       Item_B   2557        34     81             73
#
#    rating  reviews    supplier  ...  manufacturing_date  customer_gender  \
# 0     1.5      427  Supplier_C  ...          2024-01-01             Male
# 1     2.6      383  Supplier_B  ...          2024-01-02           Female
# 2     3.9       50  Supplier_A  ...          2024-01-03             Male
# 3     4.5      106  Supplier_A  ...          2024-01-04             Male
# 4     2.0       72  Supplier_C  ...          2024-01-05           Female
#
#   customer_type  payment_method transaction_id order_status delivery_time  \
# 0       Regular  Mobile Payment         T50000      Pending             2
# 1       Regular     Credit Card         T50001    Completed            12
# 2           New     Credit Card         T50002      Pending             7
# 3           VIP     Credit Card         T50003    Cancelled            13
# 4       Regular  Mobile Payment         T50004      Pending            11
#
#   return_status feedback  desercion_de_clientes
# 0  Not Returned  Average       posible abandono
# 1  Not Returned     Good                cliente
# 2      Returned  Average       posible abandono
# 3  Not Returned     Good       posible abandono
# 4      Returned     Good       posible abandono
#
# [5 rows x 23 columns]

# %%
# convertimos categoricos a numericos

le = LabelEncoder()

for col in df.select_dtypes('object'):
    df[col] = le.fit_transform(df[col])

# %%
# Separamos data set en X,y

X = df.drop(['desercion_de_clientes'],axis=1) 
y = df['desercion_de_clientes']

# %%
# Vemos la estructura 

print(X.shape)
print(y.shape)
# Out:
# (5000, 22)
# (5000,)

# %%
# Separamos en entrenamiento y en prueba y asignamos el tamanho del entrenamiento 

X_train,X_test, y_train,y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
# Normalizamos

# escala = StandardScaler()
# X_train = escala.fit_transform(X_train)
# X_test= escala.transform(X_test)

# %%
# usamos nuestra funcion para ver el mejor k
mejor_k, precision = k_optimo(X_train, y_train, X_test, y_test)

# %%
# Desempaquetamos nuestra tupla ya que la funcion devuelve una lista de tuplas 

k, accu = zip(*precision)

# %%
# graficamos 

plt.figure(figsize=(10, 3))
plt.plot(k,accu, marker='o', label='Accuracy')
plt.axvline(mejor_k[0], linestyle='--',color='r', label=f'Mejor K = {mejor_k[0]}')

plt.xlabel('Ks')
plt.ylabel('Precision')
plt.title('Mejor K para KNN')
plt.legend()
plt.show()

# %% [markdown]
# Aqui podemos observar que los mejores valores de  k en el rango de 1 al 100 con numeros impares  es el 47 el que nos devuelve mejor precision

# %%
# Entrenamos nuestro modelo con k = 47 que fue el mejor resultado de nuestra prueba 

knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
# predecimos

y_pred = knn.predict(X_test)

# %%
# Vemos la precision

print(f'Precision : {accuracy_score(y_test, y_pred)}')
# Out:
# Precision : 0.818

# %% [markdown]
# Vemos que efectivamente los resultados fueron los esperados pero aun asi haremos  un evaluo de nuestras columnas para ver cual afecta mas a nuestro modelo y ver si podemos eliminar algunas columnas lo cual hara nuestro modelo mas optimo

# %%
# vemos que features tienen mas peso en nuestro modelo 

score = permutation_importance(knn, X_test, y_test, scoring='accuracy',random_state=42)
importancia = score.importances_mean

# %%
# Graficamos

plt.figure(figsize=(10, 6))
plt.bar(range(len(importancia)), importancia, align='center')
plt.xticks(range(len(importancia)), X.columns, rotation=90)
plt.xlabel('Características')
plt.title('Feature Importance ')
plt.show()

# %% [markdown]
# hasta los momentos vemos que  las columnas que estan haciendo efecto a nuestros modelos son:
#
# `'employee_id','product_id', 'price', 'discount', 'reviews','stock', 'sold_quantity','purchase_cost', 'profit', 'expiry_date', 'manufacturing_date','transaction_id'`

# %%
# Separamos nuestra target denuevo solo dejando las columnas que tienen mas peso en nuestro modelo

X = df[['employee_id','product_id','price','discount','final_price',
        'stock','sold_quantity','reviews','purchase_cost',
        'profit','expiry_date','manufacturing_date','shelf_number',
        'transaction_id',]]

y = df['return_status']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[499], line 3
#       1 # Separamos nuestra target denuevo solo dejando las columnas que tienen mas peso en nuestro modelo
# ----> 3 X = df[['employee_id','product_id','price','discount','final_price',
#       4         'stock','sold_quantity','reviews','purchase_cost',
#       5         'profit','expiry_date','manufacturing_date','shelf_number',
#       6         'transaction_id',]]
#       8 y = df['return_status']
#
# File c:\Users\gabri\AppData\Local\pypoetry\Cache\virtualenvs\ml-CWkbb4YO-py3.11\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\gabri\AppData\Local\pypoetry\Cache\virtualenvs\ml-CWkbb4YO-py3.11\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\gabri\AppData\Local\pypoetry\Cache\virtualenvs\ml-CWkbb4YO-py3.11\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['final_price', 'shelf_number'] not in index"

# %%
X_train,X_test, y_train,y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
# usamos nuestra funcion para ver el mejor k
mejor_k, precision = k_optimo(X_train, y_train, X_test, y_test)

# %%
# Desempaquetamos nuestra tupla ya que la funcion devuelve una lista de tuplas 

k, accu = zip(*precision)

# %%
# graficamos 

plt.figure(figsize=(10, 3))
plt.plot(k,accu, marker='o', label='Accuracy')
plt.axvline(mejor_k[0], linestyle='--',color='r', label=f'Mejor K = {mejor_k[0]}')

plt.xlabel('Ks')
plt.ylabel('Precision')
plt.title('Mejor K para KNN')
plt.legend()
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=75)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=75)

# %%
y_pred = knn.predict(X_test)

# %%
print(f'Precision : {accuracy_score(y_test, y_pred)}')
# Out:
# Precision : 0.529
